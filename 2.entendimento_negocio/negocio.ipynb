# %% [markdown]
# *"Na criação do código, temos a possibilidade de utilizar o Jupyter Notebook, aproveitando todos os seus recursos para melhorar a comunicação entre os envolvidos. Sempre com o objetivo de registrar as informações da melhor forma possível, tanto para os colegas e amigos da profissão quanto para o seu eu do futuro."*

# %% [markdown]
# <div style="margin-top: 40px; padding-bottom: 10px; border-bottom: 3px solid #E65100;">
#   <h2 style="margin: 0; font-size: 1.9em; color: #FF9800; font-family: 'Segoe UI', sans-serif;">
#     🧾 Sumário
#   </h2>
# </div>

# %% [markdown]
# - [Entendimento do Negócio](#1)
# - [Objetivos](#2)
# - [Entendimento do Problema](#3)
# - [Público Alvo / Clientes Potenciais](#4)
# - [Importância e Relevância](#5)
# - [O Que Está Sendo Solucionado](#6)
#     - [Impacto Direto](#7)
# - [Oportunidades de Negócio e Mercado](#8)
# - [Benefícios e Melhorias Esperadas](#9)
# - [Referências](#10)

# %% [markdown]
# <a id = '1'> </a>
# #
#
# <div style="margin-top: 40px; padding-bottom: 10px; border-bottom: 3px solid #E65100;">
#   <h2 style="margin: 0; font-size: 1.9em; color: #FF9800; font-family: 'Segoe UI', sans-serif;">
#     💼 Entendimento do Negócio
#   </h2>
# </div>
#
# <p style="font-size: 1.15em; color: #4E342E; line-height: 1.6; text-align: justify;">
#     O consumo de energia é um dos principais desafios enfrentados por edificações modernas, impactando diretamente em custos operacionais, sustentabilidade e conforto dos ocupantes. Este projeto tem como finalidade <strong>compreender e prever o comportamento energético</strong> de um ambiente simulado, utilizando um conjunto de dados sintético que representa condições reais.
# </p>
#
# <p style="font-size: 1.15em; color: #4E342E; line-height: 1.6; text-align: justify;">
#     Com variáveis que envolvem fatores como <mark style="background-color: #FFE082; padding: 2px 4px; border-radius: 4px;">temperatura, umidade, ocupação, uso de HVAC e iluminação, e energia renovável</mark>, é possível desenvolver modelos de aprendizado de máquina que antecipem padrões de consumo energético, auxiliando em estratégias de <strong>eficiência e otimização</strong>.
# </p>
#
# <p style="font-size: 1.15em; color: #4E342E; line-height: 1.6; text-align: justify;">
#     O público-alvo para essa solução inclui <strong>empresas de energia, gestores prediais, startups de tecnologia limpa e instituições públicas</strong>, interessados em reduzir gastos, automatizar decisões e melhorar o desempenho energético de suas instalações.
# </p>
#
# <p style="font-size: 1.15em; color: #4E342E; line-height: 1.6; text-align: justify;">
#     Ao aplicar <strong>ferramentas de ciência e análise de dados</strong> no setor de energia elétrica, espera-se obter <strong>soluções que melhorem a qualidade do trabalho e dos serviços prestados</strong>, por meio da <strong>identificação de desperdícios</strong>, <strong>previsão de picos de consumo</strong> e até mesmo <strong>recomendações de ações sustentáveis</strong>.
#     Além disso, o entendimento inicial do negócio é fundamental para alinhar o time de desenvolvimento com a solução esperada pelo cliente ou pela área demandante, ou seja, <strong>garantir que o resultado final esteja de acordo com as necessidades de quem irá utilizá-lo</strong>.
# </p>

# %%
import base64
from IPython.display import HTML

with open("C:/Users/Yago/Desktop/GitHubLocal/projeto_previsao_consumo_energia/imgs/entendimento_negocio/info.png", "rb") as f:
    image_data = f.read()
    encoded = base64.b64encode(image_data).decode('utf-8')

html = f"""
<div style="display: flex; align-items: center; justify-content: space-between;">
  <div style="flex: 1; padding-right: 20px;">
<p style="text-align: justify;">
  Uma outra aplicação famosa destes algoritmos é na <strong>previsão de energia renovável</strong>, principalmente fontes eólicas e fotovoltaicas. Através de dados históricos de medição e dados de operação, é
  possível prever com uma boa assertividade o quanto uma planta de geração será capaz de produzir em energia elétrica. <strong>Esta é uma área que ainda existem muitos estudos sendo realizados</strong>. [2]
</p>
<p style="text-align: justify;">
  <strong>As aplicações dos algoritmos de machine learning no setor elétrico são infinitas</strong>. A grande dificuldade é conseguir modelar o processo em termos computacionais para que eles possam representar com fidelidade os fenômenos que acontecem na realidade. Um outro impasse que o setor
  elétrico apresenta é a <strong>disponibilidade de dados estruturados e de qualidade</strong>. É comum algumas
  distribuidoras nem possuírem dados do processo que pretendem otimizar, precisando investir em
  uma etapa anterior, que é a de <strong>instrumentação e aquisição de dados</strong>. Esta etapa é custosa e muitas
  vezes <strong>desencoraja os investimentos em tecnologia no setor elétrico</strong>. [2]
</p>
  </div>
  <div style="flex: 1;">
    <img src="data:image/png;base64,{encoded}" alt="Notícia" style="max-width: 100%; border-radius: 8px;">
  </div>
</div>
"""

HTML(html)
# Out:
# <div style="display: flex; align-items: center; justify-content: space-between;">
#   <div style="flex: 1; padding-right: 20px;">
# <p style="text-align: justify;">
#   Uma outra aplicação famosa destes algoritmos é na <strong>previsão de energia renovável</strong>, principalmente fontes eólicas e fotovoltaicas. Através de dados históricos de medição e dados de operação, é
#   possível prever com uma boa assertividade o quanto uma planta de geração será capaz de produzir em energia elétrica. <strong>Esta é uma área que ainda existem muitos estudos sendo realizados</strong>. [2]
# </p>
# <p style="text-align: justify;">
#   <strong>As aplicações dos algoritmos de machine learning no setor elétrico são infinitas</strong>. A grande dificuldade é conseguir modelar o processo em termos computacionais para que eles possam representar com fidelidade os fenômenos que acontecem na realidade. Um outro impasse que o setor
# ...

# %% [markdown]
# <a id = '3'> </a>
#
# ### 🔍 Entendimento do Problema
# <p style="font-size: 1.15em; color: #4E342E; line-height: 1.6; text-align: justify;">
#     Este projeto trata-se de um <strong>caso de previsão</strong>, mais especificamente de um <strong>problema de regressão</strong>. O objetivo é estimar o consumo energético de um ambiente com base em variáveis contextuais, como temperatura, umidade, ocupação, uso de HVAC e iluminação, entre outras. A ideia é prever valores contínuos, ou seja, o consumo de energia em unidades de medida específicas (kWh, por exemplo), o que caracteriza um problema de <strong>regressão</strong>.
# </p>
# <p style="font-size: 1.15em; color: #4E342E; line-height: 1.6; text-align: justify;">
#     Em um problema de regressão, o modelo tenta identificar a relação entre as variáveis de entrada (como as condições ambientais e comportamentais) e a variável de saída, que é o consumo de energia. O objetivo é criar um modelo capaz de prever com precisão o consumo energético para um futuro próximo, baseando-se em dados históricos e variáveis que influenciam o uso de energia.
# </p>
# <p style="font-size: 1.15em; color: #4E342E; line-height: 1.6; text-align: justify;">
#     Como a tarefa é prever um valor contínuo, o modelo desenvolvido visa fornecer uma previsão quantitativa, e não uma classificação de categorias ou grupos. Isso faz com que a abordagem de regressão seja a mais adequada para este tipo de problema.
# </p>

# %% [markdown]
# <a id="2"></a>
#
# <div style="margin-top: 40px; padding-bottom: 10px; border-bottom: 3px solid #E65100;">
#   <h4 style="margin: 0; font-size: 1.5em; color: #FF9800; font-family: 'Segoe UI', sans-serif;">
#     🔷 Objetivos
#   </h4>
# </div>
#
# <div style="margin-top: 10px; font-size: 1.05em; color: #4E342E; line-height: 1.6; text-align: justify; font-family: 'Segoe UI', sans-serif;">
#   <p>
#     O principal objetivo deste projeto é <strong>prever o consumo de energia</strong> em ambientes comerciais ou institucionais com base em uma série de variáveis que influenciam diretamente a demanda energética, como <strong>temperatura, ocupação, uso de iluminação, HVAC (aquecimento, ventilação e ar-condicionado), entre outros</strong>.
#   </p>
#
#   <p>
#     Além da construção do <strong>modelo preditivo</strong>, será desenvolvido também <strong>um pequeno visualizador de dados</strong>, no formato de um <strong>dashboard interativo</strong>, que permita explorar os dados históricos e as previsões de forma prática e intuitiva. Isso tornará os resultados mais acessíveis e facilitará a tomada de decisão por parte dos usuários e gestores.
#   </p>
#
#   <p>Com esse modelo e o painel visual, será possível:</p>
#
#   <ul style="padding-left: 20px;">
#     <li><strong>⚡ Antecipar picos de consumo</strong><br>
#       Prever momentos de maior demanda energética para melhor planejamento e uso eficiente dos recursos.
#     </li>
#     <li><strong>📈 Aprimorar estratégias de eficiência energética</strong><br>
#       Utilizar dados históricos e variáveis ambientais para ajustar o funcionamento de sistemas como HVAC e iluminação.
#     </li>
#     <li><strong>💰 Reduzir custos operacionais</strong><br>
#       Com previsões precisas, é possível minimizar o desperdício de energia e otimizar os gastos com eletricidade.
#     </li>
#     <li><strong>🌱 Incentivar o uso consciente e estratégico de fontes renováveis</strong><br>
#       Analisar a contribuição da energia renovável no consumo total e promover ações sustentáveis dentro do ambiente.
#     </li>
#   </ul>
# </div>

# %% [markdown]
# <a id = '4'> </a>
# #
#
# ### 👥 Público-Alvo / Clientes Potenciais
#
# - 🏢 **Empresas de energia**
#   Que desejam oferecer serviços inteligentes de previsão e gestão energética aos seus clientes.
#
# - 🏬 **Gestores de edifícios comerciais, industriais ou educacionais**
#   Que buscam reduzir gastos com energia e melhorar a eficiência de suas instalações.
#
# - 🚀 **Startups e empresas de tecnologia limpa (cleantech)**
#   Que trabalham com soluções de IoT, smart buildings e energia sustentável.
#
# - 🏛️ **Governo e instituições públicas**
#   Especialmente aquelas focadas em políticas de sustentabilidade e redução de emissão de carbono.
#
# - 🛠️ **Consultorias ambientais e de engenharia**
#   Que prestam serviços de diagnósticos energéticos e otimização de consumo para seus clientes.

# %% [markdown]
# <a id = '5'> </a>
#
# ### 📈 Importância e Relevância
#
# O consumo de energia está diretamente ligado a **questões econômicas, ambientais e operacionais**. Com um modelo preditivo bem treinado, podemos:
#
# - 🏗️ **Aumentar a eficiência operacional dos edifícios**
#   Identificando padrões de uso e otimizando o funcionamento de sistemas como HVAC e iluminação.
#
# - 🌍 **Reduzir o impacto ambiental**, promovendo o uso de **energia renovável**
#   Compreendendo melhor o balanço entre consumo e geração limpa.
#
# - 🧠 **Ajudar no planejamento e na tomada de decisão baseada em dados**
#   Fornecendo previsões e insights que orientam estratégias energéticas mais inteligentes.
#
# - 📊 **Apoiar políticas públicas e metas ESG (Ambiental, Social e Governança)**
#   Facilitando o acompanhamento de indicadores sustentáveis e metas de descarbonização.

# %% [markdown]
# <a id = '6'> </a>
#
# ### 🧩 O Que Está Sendo Solucionado
#
# - ❗ **Problema atual:**
#   Falta de visibilidade em tempo real e previsão acurada do consumo energético de um ambiente.
#
# - 💡 **Solução proposta:**
#   Criar um **modelo de aprendizado de máquina** que estime o consumo com base em **variáveis contextuais** como temperatura, ocupação, uso de iluminação, feriados, entre outros.
#
# #### 📌 Impacto Direto:
#
# - 🔧 **Otimização do uso de sistemas HVAC e iluminação**
#   Com previsões mais precisas, é possível ajustar o funcionamento desses sistemas de forma eficiente.
#
# - 🔋 **Redução de desperdício de energia**
#   Evitando consumo desnecessário e melhorando o desempenho energético.
#
# - 🧭 **Tomadas de decisão mais estratégicas quanto à ocupação e operação de ambientes**
#   Com dados mais claros, gestores podem planejar o uso dos espaços com maior inteligência.
#
# - ⚖️ **Melhoria no planejamento de energia e balanceamento da rede** *(no caso das distribuidoras)*
#   Previsões precisas auxiliam empresas de energia a distribuírem melhor seus recursos.

# %% [markdown]
# ### 🔍 Oportunidades de Negócio e Mercado
#
# - 🌍 **Crescimento do mercado global de eficiência energética**
#   Impulsionado por **regulamentações ambientais**, aumento das tarifas de energia e pela busca por redução de custos.
#
# - 🏙️ **Avanço dos smart buildings e smart grids**
#   Amplia o espaço para **soluções baseadas em dados**, conectadas e inteligentes.
#
# - 🤖 **Potencial integração com IoT e sistemas de automação predial**
#   Possibilita o uso em tempo real de sensores e dispositivos para atuação automatizada e eficiente.
#
# - ♻️ **Alinhamento com os Objetivos de Desenvolvimento Sustentável (ODS)**
#   Especialmente o **ODS 7 - Energia Limpa e Acessível**, promovendo sustentabilidade e inovação no setor energético.

# %% [markdown]
# ### 🚀 Benefícios e Melhorias Esperadas
#
# - 💰 **Economia direta nos custos operacionais**
#   Através do uso otimizado de sistemas como HVAC e iluminação, reduzindo desperdícios.
#
# - 🌿 **Redução da pegada de carbono**
#   Contribuindo para práticas mais sustentáveis e alinhadas às metas ambientais.
#
# - 🌡️ **Melhoria no conforto térmico e uso inteligente dos recursos**
#   Ajustes mais precisos nas condições internas com base em dados preditivos.
#
# - ☀️ **Análise de cenários para investimentos em energia renovável**
#   Identificação de oportunidades para geração própria e integração com a rede.
#
# - 📊 **Melhor entendimento do comportamento energético dos ambientes**
#   Suporte à tomada de decisões estratégicas, baseadas em padrões e previsões.

# %% [markdown]
# <a id = '2'> </a>
# #
#
# <div style="margin-top: 40px; padding-bottom: 10px; border-bottom: 3px solid #E65100;">
#   <h4 style="margin: 0; font-size: 1.5em; color: #FF9800; font-family: 'Segoe UI', sans-serif;">
#      🔷 Referências
#   </h4>
# </div>

# %% [markdown]
# [1] MRSIMPLE07. Energy Consumption Prediction. Kaggle, 2023. Disponível em: https://www.kaggle.com/datasets/mrsimple07/energy-consumption-prediction/data. Acesso em: 15 maio 2025.
#
# [2] BRASIL. Ministério da Educação. Machine Learning. Disponível em: https://www.gov.br/mec/pt-br/assuntos/ept/profissionais-futuro/MachineLearning__1_2.pdf. Acesso em: 16 maio 2025.
