# %% [markdown]
# <div style="margin-top: 40px; padding-bottom: 10px; border-bottom: 3px solid #E65100;">
#   <h2 style="margin: 0; font-size: 1.9em; color: #FF9800; font-family: 'Segoe UI', sans-serif;">
#     📑 Sumário
#   </h2>
# </div>
#
# <p style="margin-top: 10px; font-size: 1.05em; color: #FFFFFF; line-height: 1.6; text-align: justify; font-family: 'Segoe UI', sans-serif;">
#
#
#   #
# </p>

# %% [markdown]
# - [Imports](#1)
#     - [Carregando o conjunto de dados](#2)
# - [Objetivos](#3)
# - [Entendimento do Conjunto de Dados](#4)
# - [Construção do dicionário dos dados](#5)
# - [Variável target](#6)
# - [Referências](#7)

# %% [markdown]
# <a id = '1'></a>
# #
#
# <div style="margin-top: 40px; padding-bottom: 10px; border-bottom: 3px solid #E65100;">
#   <h2 style="margin: 0; font-size: 1.9em; color: #FF9800; font-family: 'Segoe UI', sans-serif;">
#     📦 Imports
#   </h2>
# </div>
#
# <p style="margin-top: 10px; font-size: 1.05em; color: #000000; line-height: 1.6; text-align: justify; font-family: 'Segoe UI', sans-serif;">
# Nesta seção, serão realizados os imports das bibliotecas e pacotes necessários para o desenvolvimento do notebook, importantes para gerar os dicionários dos dados.
#
#   #
# </p>

# %%
# Imagens:
from IPython.display import display, Markdown, Image

# Manipulação de dados:
import numpy as np
import pandas as pd

# Gráficos:
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)


colors = ["#9467bd", "#057476", "#FF7A00"]
# sns.set_style("whitegrid")
sns.set_theme(style="ticks")
sns.set_palette(sns.color_palette(colors))

# %% [markdown]
# <a id = '2'></a>
# #
#
# <div style="margin-top: 40px; padding-bottom: 10px; border-bottom: 3px solid #E65100;">
#   <h4 style="margin: 0; font-size: 1.5em; color: #FF9800; font-family: 'Segoe UI', sans-serif;">
#     💾 Carregando o conjunto de dados
#   </h4>
# </div>
#
# <p style="margin-top: 10px; font-size: 1.05em; color: #000; line-height: 1.6; text-align: justify; font-family: 'Segoe UI', sans-serif;">
# Nesta etapa, realizamos a importação do conjunto de dados que será utilizado ao longo do projeto.
# </p>

# %%
df_raw = pd.read_csv(r"C:\Users\Yago\Desktop\GitHubLocal\projeto_previsao_consumo_energia\1.dados\df_raw.csv")

# %% [markdown]
# <a id = '3'></a>
#
# #
#
# <div style="margin-top: 40px; padding-bottom: 10px; border-bottom: 3px solid #E65100;">
#   <h2 style="margin: 0; font-size: 1.9em; color: #FF9800; font-family: 'Segoe UI', sans-serif;">
#     🏆 Objetivos
#   </h2>
# </div>
#
# <p style="margin-top: 10px; font-size: 1.05em; color: #FFFFFF; line-height: 1.6; text-align: justify; font-family: 'Segoe UI', sans-serif;">
#   Breve descrição dos principais objetivos da seção.
#
#   #
# </p>

# %% [markdown]
# <div style="border-left: 6px solid #FF9800; background-color: #f9f9f9; padding: 15px; border-radius: 10px; box-shadow: 0px 2px 4px rgba(0,0,0,0.1);">
#   <h3 style="margin: 0; color: #FF5722;">📌 Objetivo Geral</h3>
#
#   <p style="margin-top: 5px; color: rgb(0, 0, 0);">
#
# - Obter uma visão geral do conjunto de dados;
#
# - Identificar a estrutura, os tipos de variáveis e possíveis padrões ou inconsistências iniciais;
#
# - Construir um dicionário de dados detalhad;
#
# - Documentar cada variável com nome, tipo, descrição e papel na análise, facilitando a interpretação e a comunicação dos resultados;
#
# - Analisar a variável que será prevista (target), identificando sua distribuição, natureza (contínua ou categórica) e importância no contexto da modelagem.
#   </p>
# </div>

# %% [markdown]
# <a id = '4'></a>
# #
#
# <div style="margin-top: 40px; padding-bottom: 10px; border-bottom: 3px solid #E65100;">
#   <h2 style="margin: 0; font-size: 1.9em; color: #FF9800; font-family: 'Segoe UI', sans-serif;">
#     📚 Entendimento do Conjunto de Dados
#   </h2>
# </div>
#
# <p style="font-size: 1.15em; color: #4E342E; line-height: 1.6; text-align: justify;">
#     Nesta seção, serão exploradas as <mark style="background-color: #FFE082; padding: 2px 4px; border-radius: 4px;">principais características</mark> do conjunto de dados, como os tipos de variáveis, suas descrições, formatos e possíveis padrões.
#     O objetivo é <strong>obter uma visão geral</strong> que guie as etapas seguintes da análise.
#
# #
# </p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="border-left: 6px solid #FFA726; background-color:rgb(222, 222, 222) padding: 15px 20px; border-radius: 10px; margin: 20px 0; box-shadow: 0 2px 5px rgba(0,0,0,0.1); font-family: 'Segoe UI', sans-serif;">
#   <h3 style="margin: 0 0 10px; color: #FB8C00;">📁 Dataset: <strong>Energy-consumption-prediction</strong></h3>
#
#   <p style="margin: 5px 0; font-size: 1.05em;">
#     <strong>📌 Descrição:</strong> Predict the Energy Consumption
#   </p>
#
#   <p style="margin: 5px 0; font-size: 1.05em;">
#     <strong>👤 Autor:</strong> MrSimple &nbsp;·&nbsp; <strong>
#   </p>
#
#   <p style="margin: 5px 0; font-size: 1.05em;">
#     <strong>📅 Publicado em:</strong> 1 ano atrás
#   </p>
#
#   <p style="margin: 5px 0; font-size: 1.05em;">
#     <strong>💻 Códigos disponíveis:</strong> 10 notebooks &nbsp;|&nbsp; <strong>👁️ Visualizações:</strong> 22.1K &nbsp;|&nbsp; <strong>📥 Downloads:</strong> 4558
#   </p>
# </div>

# %% [markdown]
# <div style="border-left: 6px solid #FF9800; background-color: #f9f9f9; padding: 15px; border-radius: 10px; box-shadow: 0px 2px 4px rgba(0,0,0,0.1);">
#   <h3 style="margin: 0; color: #FF5722;">⚠️ Observação</h3>
#
#   <p style="margin-top: 5px; color: rgb(0, 0, 0);">
#   Informações obtidas no dia 24.04.2025
#   </p>
# </div>

# %% [markdown]
# <div align="left" style="margin-top: 30px;">
#
#   <a href="https://www.kaggle.com/datasets/mrsimple07/energy-consumption-prediction/data" target="_blank" style="
#     background-color: #FB8C00;
#     color: white;
#     padding: 12px 20px;
#     font-size: 16px;
#     font-family: sans-serif;
#     border-radius: 8px;
#     text-decoration: none;
#     display: inline-block;
#     font-weight: bold;
#     border: 2px solid rgb(110, 109, 108); /* Corrigido com a cor laranja */
#     box-sizing: border-box; /* Garante que o padding e a borda não se sobreponham */
#   ">
#     📥 Acessar a Fonte dos Dados
#   </a>
#
#   <p style="margin-top: 10px; font-size: 14px; font-family: sans-serif; color: #555;">
#     📚 Fonte do conjunto de dados:
#     <a href="https://www.kaggle.com/datasets/mrsimple07/energy-consumption-prediction/data" target="_blank" style="color: #F57C00; text-decoration: none;">
#       Kaggle - Energy-consumption-prediction
#     </a>
#   </p>
#
# </div>

# %% [markdown]
# <div style="text-align: justify; font-family: 'Segoe UI', sans-serif; font-size: 1.05em; line-height: 1.6; color: #000;">
#   Este conjunto de dados engloba uma <strong>gama diversificada de características</strong>, incluindo
#   <strong>temperatura</strong>, <strong>umidade</strong>, <strong>ocupação</strong>, <strong>uso de HVAC</strong> e
#   <strong>iluminação</strong>, <strong>contribuições de energia renovável</strong> e muito mais.
#
#   Cada registro de data e hora fornece um <strong>instantâneo de um ambiente hipotético</strong>, permitindo
#   <strong>análises e modelagem aprofundadas</strong> dos comportamentos de consumo de energia.
#
#   Mergulhe nas <strong>nuances deste conjunto de dados sintéticos</strong>, projetado para <strong>emular cenários do mundo real</strong>,
#   e desvende as <strong>complexidades que influenciam o uso de energia</strong>.
#
#   Seja para se aprofundar em <strong>modelagem preditiva</strong> ou <strong>aprimorar suas habilidades de análise de dados</strong>,
#   este conjunto de dados oferece um <strong>ambiente dinâmico para experimentação e descoberta</strong>.
#   <sup>[1]</sup>
# </div>

# %% [markdown]
# <a id = '5'></a>
# #
#
# <div style="margin-top: 40px; padding-bottom: 10px; border-bottom: 3px solid #E65100;">
#   <h2 style="margin: 0; font-size: 1.9em; color: #FF9800; font-family: 'Segoe UI', sans-serif;">
#     📖 Construção do dicionário dos dados
#   </h2>
# </div>
#
# <p style="margin-top: 8px; font-size: 1.1em; color: #4A4A4A;">
#     Breve descrição dos principais objetivos da seção.
#   </p>
#
#   #
# </p>

# %% [markdown]
# <div style="text-align: justify">
#
# Nessa primeira etapa é **muito importante mapeamos os nossos dados**, primeiro para conhecer cada um e **identificar qual característica ou informação aquele dado expressa**. Esse dicionário também será importante para **conferirmos se o tipo de dado está corretamente especificado**, e será útil para **consultarmos essas informações no decorrer do projeto**, como, por exemplo, **dividir os dados em categorias e realizar análises com base no tipo do dado**.
#
# <br>
#
#  - **Organização e Padronização:** O dicionário de dados **descreve as variáveis, suas definições, tipos de dados, unidades e restrições**. Essa documentação **organiza os dados e garante que todos entendam o que cada campo representa**, evitando ambiguidade.
#
# <br>
#
# - **Escalabilidade:** Se o projeto for expandido no futuro, o dicionário de dados **ajuda a integrar novos dados ou variáveis de forma estruturada** e garante que a base existente seja preservada.
#
# <br>
#
# - **Facilita a Colaboração:** Um dicionário de dados é uma **referência para todos os envolvidos no projeto** (equipe de TI, analistas, usuários finais). Isso torna mais fácil para novos membros da equipe **entenderem rapidamente a estrutura dos dados**.
#
# <br>
#
# - **Documentação e Auditoria:** Em projetos de longo prazo, o dicionário de dados **serve como um registro que documenta todas as variáveis e suas modificações**. Isso é importante para auditorias, **para rastrear a origem e a finalidade dos dados** e entender mudanças feitas ao longo do tempo.
#
# </div>

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Timestamp          1000 non-null   object
#  1   Temperature        1000 non-null   float64
#  2   Humidity           1000 non-null   float64
#  3   SquareFootage      1000 non-null   float64
#  4   Occupancy          1000 non-null   int64
#  5   HVACUsage          1000 non-null   object
#  6   LightingUsage      1000 non-null   object
#  7   RenewableEnergy    1000 non-null   float64
#  8   DayOfWeek          1000 non-null   object
#  9   Holiday            1000 non-null   object
#  10  EnergyConsumption  1000 non-null   float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 86.1+ KB

# %%
data_dict = pd.DataFrame([
    {
        "variavel": "Timestamp",
        "variavel-pt": "Data e Hora",
        "descricao-pt": "Momento exato em que as condições ambientais e operacionais foram registradas em um ambiente simulado.",
        "descricao-en": "Exact moment when environmental and operational conditions were recorded in a simulated environment.",
        "tipo": "Qualitativa",
        "subtipo": "Nominal"
    },
    {
        "variavel": "Temperature",
        "variavel-pt": "Temperatura",
        "descricao-pt": "Temperatura ambiente (°C) no momento do registro, fator que influência diretamente o uso de climatização.",
        "descricao-en": "Ambient temperature (°C) at the time of the record, which directly impacts HVAC usage.",
        "tipo": "Quantitativa",
        "subtipo": "Contínua"
    },
    {
        "variavel": "Humidity",
        "variavel-pt": "Umidade",
        "descricao-pt": "Umidade relativa do ar (%) no ambiente, relacionada ao conforto térmico e à operação do HVAC.",
        "descricao-en": "Relative humidity (%) in the environment, related to thermal comfort and HVAC operation.",
        "tipo": "Quantitativa",
        "subtipo": "Contínua"
    },
    {
        "variavel": "SquareFootage",
        "variavel-pt": "Área Construída",
        "descricao-pt": "Área total do edifício em pés quadrados, importante para estimar a demanda energética.",
        "descricao-en": "Total building area in square feet, important for estimating energy demand.",
        "tipo": "Quantitativa",
        "subtipo": "Contínua"
    },
    {
        "variavel": "Occupancy",
        "variavel-pt": "Ocupação",
        "descricao-pt": "Número de pessoas presentes no edifício, influenciando o consumo de energia por iluminação, climatização e outros sistemas.",
        "descricao-en": "Number of people present in the building, affecting energy use for lighting, HVAC, and other systems.",
        "tipo": "Quantitativa",
        "subtipo": "Discreta"
    },
    {
        "variavel": "HVACUsage",
        "variavel-pt": "Uso do HVAC",
        "descricao-pt": "Nível de uso do sistema de climatização (baixo, médio, alto), que reflete as condições térmicas e de ocupação.",
        "descricao-en": "HVAC system usage level (low, medium, high), reflecting thermal and occupancy conditions.",
        "tipo": "Qualitativa",
        "subtipo": "Ordinal"
    },
    {
        "variavel": "LightingUsage",
        "variavel-pt": "Uso de Iluminação",
        "descricao-pt": "Nível de uso do sistema de iluminação (baixo, médio, alto), influenciado por ocupação e horário do dia.",
        "descricao-en": "Lighting system usage level (low, medium, high), influenced by occupancy and time of day.",
        "tipo": "Qualitativa",
        "subtipo": "Ordinal"
    },
    {
        "variavel": "RenewableEnergy",
        "variavel-pt": "Energia Renovável",
        "descricao-pt": "Energia renovável gerada (kWh) no momento do registro, contribuindo para a redução do consumo de fontes convencionais.",
        "descricao-en": "Renewable energy generated (kWh) at the time of record, reducing reliance on conventional sources.",
        "tipo": "Quantitativa",
        "subtipo": "Contínua"
    },
    {
        "variavel": "DayOfWeek",
        "variavel-pt": "Dia da Semana",
        "descricao-pt": "Dia correspondente ao registro (ex: segunda, terça...), útil para análises de padrões semanais de consumo.",
        "descricao-en": "Day corresponding to the record (e.g., Monday, Tuesday...), useful for weekly consumption patterns.",
        "tipo": "Qualitativa",
        "subtipo": "Nominal"
    },
    {
        "variavel": "Holiday",
        "variavel-pt": "Feriado",
        "descricao-pt": "Indica se o dia registrado é um feriado, o que pode impactar significativamente a ocupação e o consumo.",
        "descricao-en": "Indicates whether the recorded day is a holiday, which can significantly affect occupancy and consumption.",
        "tipo": "Qualitativa",
        "subtipo": "Nominal"
    },
    {
        "variavel": "EnergyConsumption",
        "variavel-pt": "Consumo de Energia",
        "descricao-pt": "Total de energia consumida (kWh) no ambiente simulado, sendo a variável alvo principal para análises preditivas.",
        "descricao-en": "Total energy consumed (kWh) in the simulated environment, the main target variable for predictive analysis.",
        "tipo": "Quantitativa",
        "subtipo": "Contínua"
    }
])

# %%
# apresentação do dicionário
display(data_dict.shape)
# Out:
# (11, 6)

# %%
# Apresentação do dicionário:
display(data_dict)
# Out:
#              variavel         variavel-pt  \
# 0           Timestamp         Data e Hora
# 1         Temperature         Temperatura
# 2            Humidity             Umidade
# 3       SquareFootage     Área Construída
# 4           Occupancy            Ocupação
# 5           HVACUsage         Uso do HVAC
# 6       LightingUsage   Uso de Iluminação
# 7     RenewableEnergy   Energia Renovável
# 8           DayOfWeek       Dia da Semana
# 9             Holiday             Feriado
# 10  EnergyConsumption  Consumo de Energia
#
#                                                                                                                    descricao-pt  \
# 0                        Momento exato em que as condições ambientais e operacionais foram registradas em um ambiente simulado.
# 1                     Temperatura ambiente (°C) no momento do registro, fator que influência diretamente o uso de climatização.
# ...

# %%
# Filtrando variáveis numéricas (quantitativas)
data_dict_numeric = data_dict[data_dict['tipo'] == 'Quantitativa']

# Filtrando variáveis do tipo objeto (qualitativas)
data_dict_object  = data_dict[data_dict['tipo'] != 'Quantitativa']

# %%
# Salvar o dicionário total:
data_dict.to_csv(r'C:\Users\Yago\Desktop\GitHubLocal\projeto_previsao_consumo_energia\3.entendimento_dados\dicionarios\dicionario_geral.csv', index=False)

# %%
# Salvar as variáveis numéricas em CSV
data_dict_numeric.to_csv(r'C:\Users\Yago\Desktop\GitHubLocal\projeto_previsao_consumo_energia\3.entendimento_dados\dicionarios\dicionario_var_numericas.csv', index=False)

# Salvar as variáveis do tipo objeto em CSV
data_dict_object.to_csv(r'C:\Users\Yago\Desktop\GitHubLocal\projeto_previsao_consumo_energia\3.entendimento_dados\dicionarios\dicionario_var_objeto.csv', index=False)

# %% [markdown]
# <div align="left" style="margin-top: 30px;">
#
#   <a href="https://github.com/YagoCastro/projeto_previsao_consumo_energia/blob/main/3.entendimento_dados/dicionarios/dicionario_geral.csv" target="_blank" style="
#     background-color: #FB8C00;
#     color: white;
#     padding: 12px 20px;
#     font-size: 16px;
#     font-family: sans-serif;
#     border-radius: 8px;
#     text-decoration: none;
#     display: inline-block;
#     font-weight: bold;
#     border: 2px solid rgb(90, 0, 245); /* Corrigido com a cor laranja */
#     box-sizing: border-box; /* Garante que o padding e a borda não se sobreponham */
#   ">
#     📥 Acessar o Dicionário dos dados
#   </a>
#
#   <p style="margin-top: 10px; font-size: 14px; font-family: sans-serif; color: #555;">
#     📚 Repositório do projeto:
#     <a href="https://github.com/YagoCastro/projeto_previsao_consumo_energia/blob/main/3.entendimento_dados/dicionarios/dicionario_geral.csv" target="_blank" style="color: #F57C00; text-decoration: none;">
#       Entendimento dos Dados - Dicionário Completo
#     </a>
#   </p>
#
# </div>

# %% [markdown]
# <a id = '6'></a>
# #
#
# <div style="margin-top: 40px; padding-bottom: 10px; border-bottom: 3px solid #E65100;">
#   <h2 style="margin: 0; font-size: 1.9em; color: #FF9800; font-family: 'Segoe UI', sans-serif;">
#     🎯 Variável target
#   </h2>
# </div>
#
#   #
# </p>

# %%
# Histograma da variável EnergyConsumption com cor laranja
plt.figure(figsize=(10, 6))
plt.hist(df_raw['EnergyConsumption'], bins=30, color='orange', edgecolor='black')
plt.title('Distribuição da Variável EnergyConsumption')
plt.xlabel('Consumo de Energia')
plt.ylabel('Frequência')
plt.grid(True)
plt.show()

# %% [markdown]
# <p style="text-align: justify; font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; font-size: 1.05em; color: #000;">
#   A variável <strong>EnergyConsumption (Consumo de Energia)</strong> é definida como a <strong>variável alvo</strong> deste conjunto de dados, uma vez que representa o <strong>total de energia consumida (em kWh)</strong> no ambiente simulado. Essa variável é o <strong>foco principal das análises preditivas</strong> propostas, estando diretamente relacionada ao <strong>objetivo do dataset</strong>, que é <strong>compreender os fatores que influenciam o consumo energético</strong> em diferentes condições ambientais e operacionais.
# </p>

# %% [markdown]
# <p style="text-align: justify; font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; font-size: 1.05em; color: #000;">
#   Além disso, <strong>EnergyConsumption</strong> é uma <strong>variável quantitativa contínua</strong>, apropriada para abordagens de <strong>modelagem preditiva por regressão</strong>. As demais variáveis presentes no conjunto de dados — como <strong>temperatura</strong>, <strong>umidade</strong>, <strong>ocupação</strong>, <strong>uso de HVAC</strong> e <strong>iluminação</strong>, entre outras — são consideradas <strong>variáveis explicativas (ou preditoras)</strong>, pois influenciam diretamente a <strong>variação no consumo de energia ao longo do tempo</strong>.
# </p>

# %% [markdown]
# <p style="text-align: justify; font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; font-size: 1.05em; color: #000;">
#   Assim, a escolha de <strong>EnergyConsumption</strong> como <strong>variável dependente</strong> justifica-se tanto pelo <strong>contexto do problema</strong>, quanto pela <strong>natureza quantitativa dos dados</strong

# %% [markdown]
# <a id = '7'></a>
# #
# <div style="margin-top: 40px; padding-bottom: 10px; border-bottom: 3px solid #E65100;">
#   <h2 style="margin: 0; font-size: 1.9em; color: #FF9800; font-family: 'Segoe UI', sans-serif;">
#     📘 Referências
#   </h2>
# </div>
#
#
# </p>

# %% [markdown]
# [1] MRSIMPLE07. Energy Consumption Prediction. Kaggle, 2023. Disponível em: https://www.kaggle.com/datasets/mrsimple07/energy-consumption-prediction/data. Acesso em: 15 maio 2025.
